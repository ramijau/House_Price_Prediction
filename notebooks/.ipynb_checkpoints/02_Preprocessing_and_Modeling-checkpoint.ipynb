# %% [markdown]
# # Preprocessing and Modeling

# %%
import pandas as pd
from pandas import Series
import pandas.core.algorithms as algos
import numpy as np
import seaborn as sns
import os
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats.stats as stats
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
import traceback
import re
import string
import warnings
import collections
import shap
from sklearn import __version__ as sklearn_version
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale
from sklearn.model_selection import train_test_split, cross_validate, GridSearchCV, learning_curve
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import accuracy_score, classification_report, f1_score, confusion_matrix, precision_recall_curve
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, log_loss, auc, roc_curve, roc_auc_score
from sklearn.pipeline import make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.feature_selection import SelectKBest, f_regression, f_classif
import datetime
import time

from library.sb_utils import save_file

# %%
# import data
hp = pd.read_csv('../data/house_prices.csv')
hp.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea LotShape LotConfig Neighborhood  \
# 0          60       RL         65.0     8450      Reg    Inside      CollgCr
# 1          20       RL         80.0     9600      Reg       FR2      Veenker
# 2          60       RL         68.0    11250      IR1    Inside      CollgCr
# 3          70       RL         60.0     9550      IR1    Corner      Crawfor
# 4          60       RL         84.0    14260      IR1       FR2      NoRidge
#
#   Condition1 BldgType HouseStyle  ...  GarageQual  GarageCond  PavedDrive  \
# 0       Norm     1Fam     2Story  ...          TA          TA           Y
# 1      Feedr     1Fam     1Story  ...          TA          TA           Y
# 2       Norm     1Fam     2Story  ...          TA          TA           Y
# 3       Norm     1Fam     2Story  ...          TA          TA           Y
# 4       Norm     1Fam     2Story  ...          TA          TA           Y
#
#    WoodDeckSF OpenPorchSF MoSold YrSold SaleType SaleCondition  SalePrice
# 0           0          61      2   2008       WD        Normal     208500
# 1         298           0      5   2007       WD        Normal     181500
# 2           0          42      9   2008       WD        Normal     223500
# 3           0          35      2   2006       WD       Abnorml     140000
# 4         192          84     12   2008       WD        Normal     250000
#
# [5 rows x 59 columns]

# %%
hp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 59 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1259 non-null   int64
#  1   MSZoning       1259 non-null   object
#  2   LotFrontage    1041 non-null   float64
#  3   LotArea        1259 non-null   int64
#  4   LotShape       1259 non-null   object
#  5   LotConfig      1259 non-null   object
#  6   Neighborhood   1259 non-null   object
#  7   Condition1     1259 non-null   object
#  8   BldgType       1259 non-null   object
#  9   HouseStyle     1259 non-null   object
#  10  OverallQual    1259 non-null   int64
#  11  OverallCond    1259 non-null   int64
#  12  YearBuilt      1259 non-null   int64
#  13  YearRemodAdd   1259 non-null   int64
#  14  RoofStyle      1259 non-null   object
#  15  RoofMatl       1259 non-null   object
#  16  Exterior1st    1259 non-null   object
#  17  Exterior2nd    1259 non-null   object
#  18  MasVnrType     1252 non-null   object
#  19  MasVnrArea     1252 non-null   float64
#  20  ExterQual      1259 non-null   object
#  21  ExterCond      1259 non-null   object
#  22  Foundation     1259 non-null   object
#  23  BsmtQual       1224 non-null   object
#  24  BsmtCond       1224 non-null   object
#  25  BsmtExposure   1223 non-null   object
#  26  BsmtFinType1   1224 non-null   object
#  27  BsmtFinSF1     1259 non-null   int64
#  28  BsmtUnfSF      1259 non-null   int64
#  29  TotalBsmtSF    1259 non-null   int64
#  30  HeatingQC      1259 non-null   object
#  31  CentralAir     1259 non-null   object
#  32  Electrical     1259 non-null   object
#  33  1stFlrSF       1259 non-null   int64
#  34  2ndFlrSF       1259 non-null   int64
#  35  GrLivArea      1259 non-null   int64
#  36  BsmtFullBath   1259 non-null   int64
#  37  BsmtHalfBath   1259 non-null   int64
#  38  FullBath       1259 non-null   int64
#  39  HalfBath       1259 non-null   int64
#  40  BedroomAbvGr   1259 non-null   int64
#  41  KitchenAbvGr   1259 non-null   int64
#  42  KitchenQual    1259 non-null   object
#  43  TotRmsAbvGrd   1259 non-null   int64
#  44  Fireplaces     1259 non-null   int64
#  45  GarageType     1188 non-null   object
#  46  GarageYrBlt    1188 non-null   float64
#  47  GarageFinish   1188 non-null   object
#  48  GarageArea     1259 non-null   int64
#  49  GarageQual     1188 non-null   object
#  50  GarageCond     1188 non-null   object
#  51  PavedDrive     1259 non-null   object
#  52  WoodDeckSF     1259 non-null   int64
#  53  OpenPorchSF    1259 non-null   int64
#  54  MoSold         1259 non-null   int64
#  55  YrSold         1259 non-null   int64
#  56  SaleType       1259 non-null   object
#  57  SaleCondition  1259 non-null   object
#  58  SalePrice      1259 non-null   int64
# dtypes: float64(3), int64(26), object(30)
# memory usage: 580.4+ KB

# %% [markdown]
# ### Train/Test Split

# %%
# one hot encoding
object_types = list(hp.select_dtypes('object').columns)
hp_encoded = pd.get_dummies(hp, columns=object_types)
hp_encoded.shape
# Out:
# (1259, 221)

# %%
X = hp_encoded.drop(columns='SalePrice')
y = hp_encoded['SalePrice']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=47)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 881 entries, 690 to 1159
# Columns: 220 entries, MSSubClass to SaleCondition_Partial
# dtypes: float64(3), int64(25), uint8(192)
# memory usage: 364.8 KB

# %% [markdown]
# #### Impute missing values and scale data

# %%
X_defaults_median = X_train.median()
X_defaults_median
# Out:
# MSSubClass                 50.0
# LotFrontage                69.0
# LotArea                  9248.0
# OverallQual                 6.0
# OverallCond                 5.0
#                           ...
# SaleCondition_AdjLand       0.0
# SaleCondition_Alloca        0.0
# SaleCondition_Family        0.0
# SaleCondition_Normal        1.0
# SaleCondition_Partial       0.0
# Length: 220, dtype: float64

# %%
X_tr = X_train.fillna(X_defaults_median)
X_te = X_test.fillna(X_defaults_median)

# %%
scaler = StandardScaler()
scaler.fit(X_tr)
scaler.get_feature_names_out(X_tr.columns)
X_tr_scaled = scaler.transform(X_tr)
X_te_scaled = scaler.transform(X_te)

# %%
X_tr_scaled = pd.DataFrame(X_tr_scaled, columns = X_tr.columns)
X_te_scaled = pd.DataFrame(X_te_scaled, columns = X_tr.columns)

# %% [markdown]
# ### Random Forest Regressor

# %%
# random forest regressor model
rfr = RandomForestRegressor(random_state=47)

# %%
rfr.fit(X_tr_scaled, y_train)
# Out:
# RandomForestRegressor(random_state=47)

# %%
y_tr_pred = rfr.predict(X_tr_scaled)
y_te_pred = rfr.predict(X_te_scaled)

# %%
# r2 score
print('Train r2 score: {}'.format(r2_score(y_train, y_tr_pred)))
print('Test r2 score: {}'.format(r2_score(y_test, y_te_pred)))
# Out:
# Train r2 score: 0.9848574103830834
# Test r2 score: 0.8056725052388974

# %%
# mean absolute error
print('Train mean absolute error: {}'.format(mean_absolute_error(y_train, y_tr_pred)))
print('Test mean absolute error: {}'.format(mean_absolute_error(y_test, y_te_pred)))
# Out:
# Train mean absolute error: 6356.604006810444
# Test mean absolute error: 18595.515687830688

# %% [markdown]
# #### Grid Search Cross Validation

# %%
# grid parameters
n_est = [int(n) for n in np.logspace(start=1, stop=3, num=20)]
grid_params = {'n_estimators': n_est,
               'max_depth': range (5,20,5),}
grid_params
# Out:
# {'n_estimators': [10,
#   12,
#   16,
#   20,
#   26,
#   33,
#   42,
#   54,
#   69,
#   88,
#   112,
#   143,
#   183,
#   233,
#   297,
#   379,
#   483,
#   615,
#   784,
#   1000],
#  'max_depth': range(5, 20, 5)}

# %%
rf_grid_cv = GridSearchCV(rfr, 
                          param_grid=grid_params, 
                          cv=5, 
                          n_jobs=-1,
                          verbose=True)

# %%
start_time = time.time()
rf_grid_cv.fit(X_tr_scaled, y_train)
#print("--- %s seconds ---" % (time.time() - start_time))
print('Runtime: {} seconds'.format(round(time.time() - start_time, 3)))
# Out:
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# Runtime: 283.565 seconds

# %%
print('Best Score: {}'.format(rf_grid_cv.best_score_))
print('Best Parameters: {}'.format(rf_grid_cv.best_params_))
# Out:
# Best Score: 0.8864147985865161
# Best Parameters: {'max_depth': 15, 'n_estimators': 1000}

# %%
rf_best = rf_grid_cv.best_estimator_

# %%
y_tr_pred = rf_best.predict(X_tr_scaled)
y_te_pred = rf_best.predict(X_te_scaled)
# r2 score
print('Train r2 score: {}'.format(r2_score(y_train, y_tr_pred)))
print('Test r2 score: {}'.format(r2_score(y_test, y_te_pred)))
# Out:
# Train r2 score: 0.985801594833253
# Test r2 score: 0.8043174014891653

# %%
rf_best_cv_results = cross_validate(rf_best, X_tr_scaled, y_train, cv=5)
rf_best_scores = rf_best_cv_results['test_score']
rf_best_scores
# Out:
# array([0.87951984, 0.85996902, 0.87332821, 0.90470928, 0.91454765])

# %%
np.mean(rf_best_scores), np.std(rf_best_scores)
# Out:
# (0.8864147985865161, 0.020220404504956695)

# %%
plt.subplots(figsize=(5, 3))
imps = rf_best.feature_importances_
rf_feat_imps = pd.Series(imps, index=X_train.columns).sort_values(ascending=False)
rf_feat_imps[:10].plot(kind='bar')
plt.xlabel('features')
plt.ylabel('importance')
plt.title('Best random forest regressor feature importances');

# %%
rf_neg_mae = cross_validate(rf_best, X_tr_scaled, y_train, 
                            scoring='neg_mean_absolute_error', cv=5, n_jobs=-1)
rf_neg_mae
# Out:
# {'fit_time': array([17.98217297, 18.01584291, 18.04367828, 17.98010325, 11.12126517]),
#  'score_time': array([0.1779809 , 0.17295504, 0.17023182, 0.17721391, 0.09602785]),
#  'test_score': array([-16682.58114124, -17661.48063626, -18607.90046712, -16675.89958316,
#         -16885.56087558])}

# %%
rf_mae_mean = np.mean(-1 * rf_neg_mae['test_score'])
rf_mae_std = np.std(-1 * rf_neg_mae['test_score'])
rf_mae_mean, rf_mae_std
# Out:
# (17302.684540675065, 746.1505228553333)

# %%
mean_absolute_error(y_test, rf_best.predict(X_te_scaled))
# Out:
# 18715.779173763938

# %%
fractions = [.2, .25, .3, .35, .4, .45, .5, .6, .75, .8, 1.0]
train_size, train_scores, test_scores = learning_curve(rf_best, 
                                                       X_tr_scaled, y_train, 
                                                       train_sizes=fractions)
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

# %%
plt.subplots(figsize=(10, 5))
plt.errorbar(train_size, test_scores_mean, yerr=test_scores_std)
plt.xlabel('Training set size')
plt.ylabel('CV scores')
plt.title('Cross-validation score as training set size increases')
plt.savefig('../images/CV_increasing_training_set.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# #### SHAP Analysis

# %%
shap_values = shap.TreeExplainer(rf_best).shap_values(X_tr_scaled)
shap.summary_plot(shap_values, X_tr_scaled, plot_type="bar", max_display=10)

# %%
shap.summary_plot(shap_values, X_tr_scaled, max_display=10)

# %%
shap.dependence_plot("OverallQual", shap_values, X_tr_scaled)

# %%
shap.dependence_plot("GrLivArea", shap_values, X_tr_scaled)

# %%
shap.dependence_plot("TotalBsmtSF", shap_values, X_tr_scaled)

# %%
shap.dependence_plot("YearBuilt", shap_values, X_tr_scaled)

# %%
shap.dependence_plot("BsmtFinSF1", shap_values, X_tr_scaled)

# %%
shap.dependence_plot("GarageArea", shap_values, X_tr_scaled)

# %%
shap.dependence_plot("YearRemodAdd", shap_values, X_tr_scaled)

# %%
shap.dependence_plot("LotArea", shap_values, X_tr_scaled)

# %%
shap.dependence_plot("1stFlrSF", shap_values, X_tr_scaled)

# %%
shap.dependence_plot("2ndFlrSF", shap_values, X_tr_scaled)

# %%
# save the model
modelpath = '../models'
save_file(rf_best, 'house_price_prediction_model.pkl', modelpath)
